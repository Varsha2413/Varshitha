# %%
import pandas as pd
import matplotlib.pyplot as pit
from sklearn import linear_model

# %%
df=pd.read_csv(r"C:\Users\varsh\Downloads\homeprices_banglore.csv")
df.describe()
# Out:
#               area   bedrooms       price        age
# count    20.000000  20.000000   20.000000  20.000000
# mean   1821.450000   2.900000   78.853500  28.950000
# std     864.615794   0.967906   43.761901   4.260899
# min     800.000000   1.000000   32.000000  20.000000
# 25%    1173.750000   2.000000   41.500000  25.750000
# 50%    1480.500000   3.000000   61.000000  30.000000
# 75%    2633.000000   3.250000  106.500000  32.250000
# max    3700.000000   5.000000  167.000000  35.000000

# %%
x=df.drop(columns=['price'])
print(x)
y=df.drop(columns=['bedrooms','area','age'])
#print(x.ndim)
#print(y.ndim)
# Out:
#     area  bedrooms  age
# 0   1056         2   24
# 1   2600         4   25
# 2   1440         3   26
# 3   1521         3   27
# 4   1200         2   29
# 5   1170         2   23
# 6   2732         4   20
# 7   3300         4   30
# 8   1310         3   34
# 9   3700         5   35
# 10  1800         3   33
# 11  2785         4   32
# 12  1000         2   31
# 13  1100         2   33
# 14  2250         3   25
# 15  1175         2   26
# 16  1180         3   35
# 17  1540         3   31
# 18  2770         3   30
# 19   800         1   30

# %%
model=linear_model.LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
#model.predict([[1500]])

# %%
model.coef_
# Out:
# array([[ 0.04230535,  7.54278568, -0.4069441 ]])

# %%
sqft=int(input("enter sqft :"))
bed=int(input("enter beds :"))
age=int(input("enter age :"))
amount=model.predict([[sqft,bed,age]])
print("The assessed value for the house with ",sqft,"sqft is :Rs. ",amount[0])
# Out:
# enter sqft : 6000
# enter beds : 6
# enter age : 25
# The assessed value for the house with  6000 sqft is :Rs.  [280.61858424]
# C:\Users\varsh\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(df.area,df.price,color="g",marker="D")
plt.plot(df.area,model.predict(df[['area','bedrooms','age']]))
